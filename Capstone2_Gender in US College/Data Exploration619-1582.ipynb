# %% [markdown]
# ### Introduction
# The following work provides exploration of row 286 to row 618 in file MERGED2015_16_PP.csv
#
# Please refer to CollegeScorecardDataDictionary.xlsx for detailed information about the above file.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
with open('2015_16_PP286_618.csv', encoding="latin-1") as datafile:
    df = pd.read_csv(datafile, header = 0)
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2723: DtypeWarning: Columns (8,11,1711,1712,1713,1714,1715,1729) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# #### 26. TUITIONFEE_IN in-state tuition fee
# TUITIONFEE_OUT out-of-state tuition fee

# %%
df.TUITIONFEE_IN.describe()
# Out:
# count     4303.000000
# mean     14515.126191
# std      11498.971665
# min        580.000000
# 25%       5316.000000
# 50%      12142.000000
# 75%      18048.000000
# max      73132.000000
# Name: TUITIONFEE_IN, dtype: float64

# %%
df.TUITIONFEE_IN.plot.kde()

# %%
df.TUITIONFEE_OUT.describe()
# Out:
# count     4089.000000
# mean     17285.664466
# std      10757.333888
# min        580.000000
# 25%       9100.000000
# 50%      14744.000000
# 75%      22219.000000
# max      73132.000000
# Name: TUITIONFEE_OUT, dtype: float64

# %%
df.TUITIONFEE_OUT.plot.kde()

# %% [markdown]
# Out-of state tuition is approximately 10% higher than that of the in-state tuition.

# %%
df.drop(['TUITIONFEE_PROG', 'TUITFTE', 'INEXPFTE'], axis = 1)
# Out:
#       Unnamed: 0  Unnamed: 0.1    UNITID     OPEID  OPEID6  \
# 0              0             0    100654    100200    1002
# 1              1             1    100663    105200    1052
# 2              2             2    100690   2503400   25034
# 3              3             3    100706    105500    1055
# 4              4             4    100724    100500    1005
# 5              5             5    100751    105100    1051
# 6              6             6    100760    100700    1007
# 7              7             7    100812    100800    1008
# 8              8             8    100830    831000    8310
# 9              9             9    100858    100900    1009
# 10            10            10    100937    101200    1012
# 11            11            11    101028   1218200   12182
# 12            12            12    101073   1055400   10554
# 13            13            13    101116   1303906   13039
# 14            14            14    101143    101500    1015
# ...

# %% [markdown]
# #### 27. AVGFACSAL Average Faculty salary per month

# %%
df.AVGFACSAL.describe()
# Out:
# count     4454.000000
# mean      6315.360799
# std       2353.782098
# min         63.000000
# 25%       4744.250000
# 50%       6079.000000
# 75%       7624.000000
# max      26084.000000
# Name: AVGFACSAL, dtype: float64

# %%
df.AVGFACSAL.hist(bins = 20)

# %% [markdown]
# Of the 7593 entries, only 4454 (~60%) has values. Aveage faculty salary is only 6315 with min 63 and max 26084. Most faculty salary are less than 15000 per month.

# %%
df.AVGFACSAL.isnull().sum()
# Out:
# 3139

# %% [markdown]
# #### 28. PFTFAC proportion of faculty that is full-time

# %%
df.PFTFAC.describe()
# Out:
# count    3937.000000
# mean        0.572069
# std         0.302035
# min         0.000000
# 25%         0.311900
# 50%         0.550500
# 75%         0.866500
# max         1.000000
# Name: PFTFAC, dtype: float64

# %%
df.PFTFAC.isnull().sum()
# Out:
# 3656

# %%
df.PFTFAC.hist(bins = 20)

# %% [markdown]
# Among the 3937 counts, about 800 have 100% full-time faculty, about 90 have no full-time faculty. The rest all have different proportions
# of non-full-time faculty.

# %% [markdown]
# #### 29. Completion rate
# - C150_4 completion_rate_4yr_150nt
# - C150_L4 completion_rate_less_than_4yr_150nt
# - C150_4_POOLED completion_rate_4yr_150nt_pooled
# - C150_L4_POOLED completion_rate_less_than_4yr_150nt_pooled

# %%
temp = df[['C150_4', 'C150_L4', 'C150_4_POOLED', 'C150_L4_POOLED']]
temp.hist(bins = 20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001669D800470>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001669DA05F98>]], dtype=object)

# %% [markdown]
# #### 30.Completion rate for first-time, full-time students at four-year institutions
# - C150_4_WHITE completion_rate_4yr_150_white
# - C150_4_BLACK completion_rate_4yr_150_black
# - C150_4_HISP completion_rate_4yr_150_hispanic
# - C150_4_ASIAN completion_rate_4yr_150_asian

# %%
temp = df[['C150_4_WHITE', 'C150_4_BLACK', 'C150_4_HISP', 'C150_4_ASIAN']]
temp.describe()
# Out:
#        C150_4_WHITE  C150_4_BLACK  C150_4_HISP  C150_4_ASIAN
# count   2376.000000   2199.000000   2219.00000   1874.000000
# mean       0.507560      0.375751      0.44532      0.521965
# std        0.229374      0.251949      0.26047      0.311107
# min        0.000000      0.000000      0.00000      0.000000
# 25%        0.352900      0.194050      0.27455      0.333300
# 50%        0.509400      0.340400      0.44290      0.533300
# 75%        0.666700      0.524200      0.61110      0.750000
# max        1.000000      1.000000      1.00000      1.000000

# %% [markdown]
# Completion rate: asian (52.2%) > white (50.8%) > hispanish (44.5%) > black (37.6%)

# %% [markdown]
# #### 31. I'm most interested in how gender effect the students performance. So let's explore more here.

# %% [markdown]
# By year 2
# - FEMALE_DEATH_YR2_RT   MALE_DEATH_YR2_RT   Percent of female/male students who died within 2 years at original institution
#
# - FEMALE_COMP_ORIG_YR2_RT  MALE_COMP_ORIG_YR2_RT   Percent of female/male students who completed within 2 years at original institution
#
# - FEMALE_COMP_4YR_TRANS_YR2_RT MALE_COMP_4YR_TRANS_YR2_RT    Percent of female/male students who transferred to a 4-year institution and completed within 2 years
#
# - FEMALE_COMP_2YR_TRANS_YR2_RT  MALE_COMP_2YR_TRANS_YR2_RT    Percent of female/male students who transferred to a 2-year institution and completed within 2 years
#
# - FEMALE_WDRAW_ORIG_YR2_RT  MALE_WDRAW_ORIG_YR2_RT    Percent of female/male students withdrawn from original institution within 2 years
#
# - FEMALE_WDRAW_4YR_TRANS_YR2_RT  MALE_WDRAW_4YR_TRANS_YR2_RT    Percent of female/male students who transferred to a 4-year institution and withdrew within 2 years
#
# - FEMALE_WDRAW_2YR_TRANS_YR2_RT  MALE_WDRAW_2YR_TRANS_YR2_RT    Percent of female/male students who transferred to a 2-year institution and withdrew within 2 years
#
# - FEMALE_ENRL_ORIG_YR2_RT  MALE_ENRL_ORIG_YR2_RT    Percent of female/male students who were still enrolled at original institution within 2 years
#
# - FEMALE_ENRL_4YR_TRANS_YR2_RT  MALE_ENRL_4YR_TRANS_YR2_RT    Percent of female/male students who transferred to a 4-year institution and were still enrolled within 2 years
#
# - FEMALE_ENRL_2YR_TRANS_YR2_RT  MALE_ENRL_2YR_TRANS_YR2_RT    Percent of female/male students who transferred to a 2-year institution and were still enrolled within 2 years
#
# - FEMALE_UNKN_ORIG_YR2_RT MALE_UNKN_ORIG_YR2_RT    Percent of female/male students with status unknown within 2 years at original institution
#
# - FEMALE_UNKN_4YR_TRANS_YR2_RT  MALE_UNKN_4YR_TRANS_YR2_RT    Percent of female/male students who transferred to a 4-year institution and whose status is unknown within 2 years
#
# - FEMALE_UNKN_2YR_TRANS_YR2_RT MALE_UNKN_2YR_TRANS_YR2_RT    Percent of female/male students who transferred to a 2-year institution and whose status is unknown within 2 years

# %%
df[['FEMALE_UNKN_2YR_TRANS_YR2_RT','MALE_UNKN_2YR_TRANS_YR2_RT']].describe()
# Out:
#        FEMALE_UNKN_2YR_TRANS_YR2_RT  MALE_UNKN_2YR_TRANS_YR2_RT
# count                           0.0                         0.0
# mean                            NaN                         NaN
# std                             NaN                         NaN
# min                             NaN                         NaN
# 25%                             NaN                         NaN
# 50%                             NaN                         NaN
# 75%                             NaN                         NaN
# max                             NaN                         NaN

# %% [markdown]
# Unfortunately, all these values are missing in this file. May be not empty in other files?

# %% [markdown]
# The following information contains percent of students who received a Pell Grant or never, federal loan or not, first-generation versus non
# first-generation students comparison, low-income, mid-income and high-income students, dependent versus independent students. Let's skip all these rows.

# %% [markdown]
# Similar information can be found by year 3, year 4, year 6 and year 8 for both gender. But these values are all missing too.
#
# The above information are from row 673 to row 1582. They are all missing information.

# %%
df[['FEMALE_UNKN_4YR_TRANS_YR3_RT','MALE_UNKN_4YR_TRANS_YR3_RT']].describe()
# Out:
#        FEMALE_UNKN_4YR_TRANS_YR3_RT  MALE_UNKN_4YR_TRANS_YR3_RT
# count                           0.0                         0.0
# mean                            NaN                         NaN
# std                             NaN                         NaN
# min                             NaN                         NaN
# 25%                             NaN                         NaN
# 50%                             NaN                         NaN
# 75%                             NaN                         NaN
# max                             NaN                         NaN

# %%
df[['FEMALE_UNKN_4YR_TRANS_YR4_RT','MALE_UNKN_4YR_TRANS_YR4_RT']].describe()
# Out:
#        FEMALE_UNKN_4YR_TRANS_YR4_RT  MALE_UNKN_4YR_TRANS_YR4_RT
# count                           0.0                         0.0
# mean                            NaN                         NaN
# std                             NaN                         NaN
# min                             NaN                         NaN
# 25%                             NaN                         NaN
# 50%                             NaN                         NaN
# 75%                             NaN                         NaN
# max                             NaN                         NaN

# %%
df[['FEMALE_UNKN_ORIG_YR6_RT','MALE_UNKN_ORIG_YR6_RT']].describe()
# Out:
#        FEMALE_UNKN_ORIG_YR6_RT  MALE_UNKN_ORIG_YR6_RT
# count                      0.0                    0.0
# mean                       NaN                    NaN
# std                        NaN                    NaN
# min                        NaN                    NaN
# 25%                        NaN                    NaN
# 50%                        NaN                    NaN
# 75%                        NaN                    NaN
# max                        NaN                    NaN

# %%
df[['FEMALE_UNKN_ORIG_YR8_RT','MALE_UNKN_ORIG_YR8_RT']].describe()
# Out:
#        FEMALE_UNKN_ORIG_YR8_RT  MALE_UNKN_ORIG_YR8_RT
# count                      0.0                    0.0
# mean                       NaN                    NaN
# std                        NaN                    NaN
# min                        NaN                    NaN
# 25%                        NaN                    NaN
# 50%                        NaN                    NaN
# 75%                        NaN                    NaN
# max                        NaN                    NaN

# %%
temp = df.iloc[:, 687:1489]

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7593 entries, 0 to 7592
# Columns: 802 entries, FEMALE_DEATH_YR3_RT to NOT1STGEN_YR8_N
# dtypes: float64(734), object(68)
# memory usage: 46.5+ MB

# %%
temp.describe()
# Out:
#        FEMALE_DEATH_YR3_RT  FEMALE_COMP_ORIG_YR3_RT  \
# count                  0.0                      0.0
# mean                   NaN                      NaN
# std                    NaN                      NaN
# min                    NaN                      NaN
# 25%                    NaN                      NaN
# 50%                    NaN                      NaN
# 75%                    NaN                      NaN
# max                    NaN                      NaN
#
#        FEMALE_COMP_4YR_TRANS_YR3_RT  FEMALE_COMP_2YR_TRANS_YR3_RT  \
# count                           0.0                           0.0
# mean                            NaN                           NaN
# std                             NaN                           NaN
# min                             NaN                           NaN
# 25%                             NaN                           NaN
# 50%                             NaN                           NaN
# ...

# %%
temp.isnull().sum()
# Out:
# FEMALE_DEATH_YR3_RT              7593
# FEMALE_COMP_ORIG_YR3_RT          7593
# FEMALE_COMP_4YR_TRANS_YR3_RT     7593
# FEMALE_COMP_2YR_TRANS_YR3_RT     7593
# FEMALE_WDRAW_ORIG_YR3_RT         7593
# FEMALE_WDRAW_4YR_TRANS_YR3_RT    7593
# FEMALE_WDRAW_2YR_TRANS_YR3_RT    7593
# FEMALE_ENRL_ORIG_YR3_RT          7593
# FEMALE_ENRL_4YR_TRANS_YR3_RT     7593
# FEMALE_ENRL_2YR_TRANS_YR3_RT     7593
# FEMALE_UNKN_ORIG_YR3_RT          7593
# FEMALE_UNKN_4YR_TRANS_YR3_RT     7593
# FEMALE_UNKN_2YR_TRANS_YR3_RT     7593
# MALE_DEATH_YR3_RT                7593
# MALE_COMP_ORIG_YR3_RT            7593
# MALE_COMP_4YR_TRANS_YR3_RT       7593
# MALE_COMP_2YR_TRANS_YR3_RT       7593
# MALE_WDRAW_ORIG_YR3_RT           7593
# MALE_WDRAW_4YR_TRANS_YR3_RT      7593
# MALE_WDRAW_2YR_TRANS_YR3_RT      7593
# MALE_ENRL_ORIG_YR3_RT            7593
# MALE_ENRL_4YR_TRANS_YR3_RT       7593
# MALE_ENRL_2YR_TRANS_YR3_RT       7593
# MALE_UNKN_ORIG_YR3_RT            7593
# MALE_UNKN_4YR_TRANS_YR3_RT       7593
# ...

# %%
df.to_csv('2015_16_PP619_1582.csv')
